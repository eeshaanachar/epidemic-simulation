# %%
from util import Keys
from simulation import EpidemicSimulation

# %%
network_config = {
        Keys.NODE_COUNT: 1000,
        Keys.CENTRAL_HUB_COUNT: 50,
        Keys.NETWORK_TYPE: 'ER',
        Keys.EDGE_PROBABILITY: 0.1,
        Keys.QUARANTINE_STRICTNESS: 0.8,
        Keys.QUARANTINE_PROBABILITY: 0.7,
        Keys.AVAILABLE_BEDS: 100,
        Keys.AVERAGE_IMMUNITY: 0.25,
        Keys.IMMUNITY_VARIATION: 0.25,
        Keys.AVERAGE_SOCIAL_DISTANCE: 2, # metres
        Keys.SOCIAL_DISTANCE_VARIATION: 1, # metres
        Keys.AVERAGE_SAFETY_FACTOR: 0.75,
        Keys.SAFETY_FACTOR_VARIATION: 0.1,
        Keys.AVERAGE_TRAVEL_FACTOR: 0.2,
        Keys.TRAVEL_FACTOR_VARIATION: 0.5,
        Keys.TRAVEL_BAN_STRICTNESS: 0.75,
}

virus_config = {
        Keys.AVERAGE_DURATION: 9, # days
        Keys.DURATION_VARIATION: 2, # days
        Keys.DEATH_PROBABILITY: 0.01,
        Keys.INFECTION_PROBABILITY: 0.1,
        Keys.INFECTION_RADIUS: 2, # metres
        Keys.ASYMPTOTIC_PROBABILITY: 0.1,
}

# %%
simulation = EpidemicSimulation(network_config, virus_config)
simulation.simulate()
